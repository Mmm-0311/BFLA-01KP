# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

def GetDiagram1(path_to_save, mgtoa, mgtoa2, hbde, rtea, htlob2, ty, labels):
    cfont = FontProperties(fname=r'C:\Windows\Fonts\SimSun.ttc', size=8.5)
    x = 2
    print(x)
    plt.figure(figsize=(6, 4))  # 图片的大小
    plt.rcParams["font.size"] = 8  # 字体大小
    plt.rcParams["font.family"] = 'Times New Roman'  # 字体样式采用新罗马字体
    plt.rcParams['mathtext.fontset'] = 'stix'
    plt.rcParams['xtick.direction'] = 'in'  # 刻度线向内
    plt.rcParams['ytick.direction'] = 'in'  # 将y轴的刻度方向设置向内
    width = 1

    t1x = x - width * 2
    t2x = x - width * 1
    t3x = x
    t4x = x + 1 * width
    t5x = x + width * 2

    plt.bar(t1x, mgtoa, width=width, color='r', label='LBFLA2')
    plt.bar(t2x, mgtoa2, width=width, color='tab:brown', label='LBFLA4')
    plt.bar(t3x, hbde, width=width, color='g', label='BEO')
    plt.bar(t4x, rtea, width=width, color='b', label='BMPA')
    plt.bar(t5x, htlob2, width=width, color='tab:orange', label='NBin_DE')

    plt.xticks([t1x, t2x, t3x, t4x, t5x], labels=labels, fontsize=8)

    plt.tick_params(bottom=False)
    plt.xlabel(ty, fontsize=8)
    plt.ylabel("${AS}$", fontsize=8)
    plt.legend(fontsize=6, loc='upper left', ncol=2, handletextpad=0.1, columnspacing=0.2, labelspacing=0.2)
    plt.savefig(path_to_save + ty + '_' + 'ZFG.png', format="PNG", dpi=300, bbox_inches='tight', pad_inches=0.02)
    plt.show()
    plt.close()

if __name__ == "__main__":
    path_to_save = r'D:\jupyterProject\BFLA\BFLA与七个优秀算法对比\直方图\\'
    ukp = "ukp"
    wkp = "wkp"
    skp = "skp"
    ikp = "ikp"
    # 读取文件中所有数据，注意CSV文件
    parent_path = r'D:\BaiduSyncdisk\BFLA数据\BFLA_01KP_SUVT_PF\BFLA与七个优秀算法对比\\'

    BFLA2, BFLA4, BEO, BMPA, NBin_DE, MDFSLA, BAOAHSM, BinRSA, BGPC = 1.38425, 0.86575, 11.76275, 17.66025, 58.35525, 0, 0, 0, 0

    labels = ['BFLA2', 'BFLA4', 'BEO', 'BMPA', 'NBin_DE']  # X轴
    GetDiagram1(path_to_save, BFLA2, BFLA4, BEO, BMPA, NBin_DE, "Algorithms", labels)
# Out:
# 2
